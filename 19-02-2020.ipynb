# %%
Single Linked List - Insert at End

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	// Allocate the memory for New Node
	struct Node *nn;
	nn =  (struct Node *)malloc(sizeof(struct Node));
	//Accept the value Field
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	// Make the New Node Address Field Points to NULL
	nn->Next = NULL;
	//check It having single or More than SIngle NOde
	if(S == NULL){
		S = L = nn;
	}
	else{
		L->Next = nn;
		L = nn;
	}
	printf("\n New Node Is Inserted...");
	getch();
}
void removeNode(){
	printf("\n Delete ");
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}

# %%
Single Linked List - Insert Start

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		nn->Next = S;
		S = nn;
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	printf("\n Delete ");
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}

# %%
Single Linked List -- Item sorted (Start, End, Middle)

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Enter the Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		if(nn->Data < S->Data){
			nn->Next = S;
			S = nn;
		}
		else if(nn->Data > L->Data){
			L->Next = nn;
			L = nn;
		}
		else{
			for(C=S;C->Data<nn->Data;P=C,C=C->Next);
			nn->Next = C;
			P->Next = nn;
		}
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	printf("\n Delete ");
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}

# %%
Single LInked List
Linked List:-
19 1 25 22 13
Input:-
121 2
Output:-
10 121 1 25 22 13

Input:- 
122 4
Output:-
19 1 25 122 22 13


19 1 25 22 13
Input:-
125 1
125 19 1 25 22 13

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position : ");
		scanf("%d",&pos);//1 2 3 4 ....
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;
		}		
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	printf("\n Delete ");
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}

# %%
Single Linked List : Counting of Nodes

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();
void countNodes();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Count Nodes ");
		printf("\n 5. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4 : countNodes();
			break;
			case 5: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position : ");
		scanf("%d",&pos);//1 2 3 4 ....
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;
		}		
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	printf("\n Delete ");
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}
void countNodes(){
	int cnt=0;
	if(S==NULL){
		printf("0");
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			cnt++;
		}
		printf("%d ",cnt);
	}
	getch();
}

# %%
Finding the Middle Node of the Single Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();
void countNodes();
void middleNode();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Count Nodes ");
		printf("\n 5. Middle Node ");
		printf("\n 6. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4 : countNodes();
			break;
			case 5 : middleNode();
			break;
			case 6: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position : ");
		scanf("%d",&pos);//1 2 3 4 ....
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;
		}		
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	printf("\n Delete ");
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}
void countNodes(){
	int cnt=0;
	if(S==NULL){
		printf("0");
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			cnt++;
		}
		printf("%d ",cnt);
	}
	getch();
}

void middleNode(){
	int cnt=0,x,i=1;
	for(C=S;C!=NULL;C=C->Next){
		cnt++;
	}
	if(cnt%2==0){
		x = cnt/2;
	}
	else{
		x = (cnt+1)/2;
	}
	for(C=S;i<x;C=C->Next,i++);
	printf("%d ",C->Data);
	getch();
}

# %%
Print Alternate Nodes of Single Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();
void countNodes();
void middleNode();
void alternateNodes();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Count Nodes ");
		printf("\n 5. Middle Node ");
		printf("\n 6. Alternate Nodes");
		printf("\n 7. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4 : countNodes();
			break;
			case 5 : middleNode();
			break;
			case 6 : alternateNodes();
			break;
			case 7: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position : ");
		scanf("%d",&pos);//1 2 3 4 ....
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;
		}		
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}
void countNodes(){
	int cnt=0;
	if(S==NULL){
		printf("0");
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			cnt++;
		}
		printf("%d ",cnt);
	}
	getch();
}

void middleNode(){
	int cnt=0,x,i=1;
	for(C=S;C!=NULL;C=C->Next){
		cnt++;
	}
	if(cnt%2==0){
		x = cnt/2;
	}
	else{
		x = (cnt+1)/2;
	}
	for(C=S;i<x;C=C->Next,i++);
	printf("%d ",C->Data);
	getch();
}
void alternateNodes(){
	int aa=0;
	for(C=S;C!=NULL;C=C->Next,aa++){
		if(aa%2==0){
			printf("%d",C->Data);
		}
		else{
			printf("->");	
		}
	}
	printf("%d",C->Data);
	getch();
}

# %%
Delete a Node from Start of Single Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();
void countNodes();
void middleNode();
void alternateNodes();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Count Nodes ");
		printf("\n 5. Middle Node ");
		printf("\n 6. Alternate Nodes");
		printf("\n 7. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4 : countNodes();
			break;
			case 5 : middleNode();
			break;
			case 6 : alternateNodes();
			break;
			case 7: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position : ");
		scanf("%d",&pos);//1 2 3 4 ....
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;
		}		
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	if(S==NULL){
		printf("\n Single Linked List Empty");
	}
	else{
		//Single Linked List - 1 Node
		if(S->Next==NULL){
			S = L = NULL;
		}
		else{
			C = S;
			S = S->Next;
			C->Next = NULL;
			C = NULL;//free(C);
		}
		printf("\n Node is Deleted from Start...");
	}
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}
void countNodes(){
	int cnt=0;
	if(S==NULL){
		printf("0");
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			cnt++;
		}
		printf("%d ",cnt);
	}
	getch();
}

void middleNode(){
	int cnt=0,x,i=1;
	for(C=S;C!=NULL;C=C->Next){
		cnt++;
	}
	if(cnt%2==0){
		x = cnt/2;
	}
	else{
		x = (cnt+1)/2;
	}
	for(C=S;i<x;C=C->Next,i++);
	printf("%d ",C->Data);
	getch();
}
void alternateNodes(){
	int aa=0;
	for(C=S;C!=NULL;C=C->Next,aa++){
		if(aa%2==0){
			printf("%d",C->Data);
		}
		else{
			printf("->");	
		}
	}
	printf("%d",C->Data);
	getch();
}

# %%
Delete a Node at the End of Single Linked List

# %%
#include<stdio.h>
#include<stdlib.h>
#include<conio.h>

struct Node{
	int Data;
	struct Node *Next;
}*S,*L,*C,*P;

void insertNode();
void removeNode();
void display();
void countNodes();
void middleNode();
void alternateNodes();

int main(){
	int x;
	S = L = C = P = NULL;
	while(1){
		system("cls");//clrscr()
		printf("\n Linked List Operations: ");
		printf("\n 1. Insert ");
		printf("\n 2. Remove ");
		printf("\n 3. Display ");
		printf("\n 4. Count Nodes ");
		printf("\n 5. Middle Node ");
		printf("\n 6. Alternate Nodes");
		printf("\n 7. Exit ");
		printf("\n Enter the Choice : ");
		scanf("%d",&x);
		switch(x){
			case 1: insertNode();
			break;
			case 2: removeNode();
			break;
			case 3: display();
			break;
			case 4 : countNodes();
			break;
			case 5 : middleNode();
			break;
			case 6 : alternateNodes();
			break;
			case 7: printf("\n Program is Terminating...");
			return 0;
			break;
		}
	}
	return 0;
}
void insertNode(){
	int pos,i=1;
	struct Node *nn;
	nn = (struct Node *)malloc(sizeof(struct Node));
	printf("\n Data : ");
	scanf("%d",&nn->Data);
	nn->Next = NULL;
	if(S==NULL){
		S = L = nn;
	}
	else{
		printf("\n Enter the Position : ");
		scanf("%d",&pos);//1 2 3 4 ....
		if(pos==1){
			nn->Next = S;
			S = nn;
		}
		else{
			for(C=S;i<pos;P=C,C=C->Next,i++);
			nn->Next = C;
			P->Next = nn;
		}		
	}
	printf("\n Node is Inserted...");
	getch();
}
void removeNode(){
	//Remove the Node at the End of Single Linked List
	if(S==NULL){
		printf("\n Single Linked List Empty...");
	}
	else{
		if(S->Next == NULL){
			S = L = NULL;
		}
		else{
			for(C=S;C!=L;P=C,C=C->Next);
			L = P;
			P->Next = NULL;
			P = NULL;
			C = NULL;//free(P) free(C)
		}
		printf("\n Node is deleted at the end...");l
	}
	getch();
}
void display(){
	if(S==NULL){
		printf("\n Linked List is Empty");
	}
	else{
		printf("\n Linked List : ");
		printf("\n -------------- \n");
		for(C=S;C!=NULL;C=C->Next)
		{
			printf("%d ",C->Data);
			//printf("%u ",C->Next);
		}
	}
	getch();
}
void countNodes(){
	int cnt=0;
	if(S==NULL){
		printf("0");
	}
	else{
		for(C=S;C!=NULL;C=C->Next){
			cnt++;
		}
		printf("%d ",cnt);
	}
	getch();
}

void middleNode(){
	int cnt=0,x,i=1;
	for(C=S;C!=NULL;C=C->Next){
		cnt++;
	}
	if(cnt%2==0){
		x = cnt/2;
	}
	else{
		x = (cnt+1)/2;
	}
	for(C=S;i<x;C=C->Next,i++);
	printf("%d ",C->Data);
	getch();
}
void alternateNodes(){
	int aa=0;
	for(C=S;C!=NULL;C=C->Next,aa++){
		if(aa%2==0){
			printf("%d",C->Data);
		}
		else{
			printf("->");	
		}
	}
	printf("%d",C->Data);
	getch();
}

# %%
Delete Node - For input value
